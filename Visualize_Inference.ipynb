# %%
# Inference on images pesent in data/Test_images fodler

# %%
# 1.CPU inference
# !python predict.py -p <Test_image_folder> --model_path <model_folder>

#GPU inference
# !python predict.py -p <Test_image_folder> --model_path <model_folder> --gpu <-1>

# %%
# !python predict.py -p data/Test_images --model_path data/mobilenetV2_model
# Out:
# model loaded from data/mobilenetV2_model/mobilenetV2_model_checkpoint_metric.pth
# Check Data_path= data/Test_images
# Check files_list= ['pexels-photo-69379.jpg']
# Starting Inference on image =  pexels-photo-69379.jpg
#  [INFO] Images processed!

# %%
import glob
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

images = []
for img_path in glob.glob('data/Test_images/*'):
    #if '_seg.' in img_path :
    #    images.append(mpimg.imread(img_path))
    images.append(mpimg.imread(img_path))

plt.figure(figsize=(20,10))
columns = 5
for i, image in enumerate(images):
    plt.subplot(len(images) / columns + 1, columns, i + 1)
    plt.imshow(image)
# Out:
# C:\Users\gkiran\miniconda3\envs\torch\lib\site-packages\ipykernel_launcher.py:15: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   from ipykernel import kernelapp as app
